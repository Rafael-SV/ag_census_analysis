# %%
import dask.dataframe as dd
import dask.array as da

# %%
census_02_df = dd.read_parquet('census_02.parquet')

# %%
tmp=census_02_df[census_02_df['COMMODITY_DESC'].str.contains('RHIZOMES')]

# %%
tmp.head()
# Out:
#      SOURCE_DESC SECTOR_DESC    GROUP_DESC                     COMMODITY_DESC  \
# 7882      CENSUS       CROPS  HORTICULTURE  BULBS & CORMS & RHIZOMES & TUBERS
# 7883      CENSUS       CROPS  HORTICULTURE  BULBS & CORMS & RHIZOMES & TUBERS
# 8690      CENSUS       CROPS  HORTICULTURE  BULBS & CORMS & RHIZOMES & TUBERS
# 8691      CENSUS       CROPS  HORTICULTURE  BULBS & CORMS & RHIZOMES & TUBERS
# 9476      CENSUS       CROPS  HORTICULTURE  BULBS & CORMS & RHIZOMES & TUBERS
#
#      CLASS_DESC       PRODN_PRACTICE_DESC         UTIL_PRACTICE_DESC  \
# 7882        DRY  ALL PRODUCTION PRACTICES  ALL UTILIZATION PRACTICES
# 7883        DRY               IN THE OPEN  ALL UTILIZATION PRACTICES
# 8690        DRY  ALL PRODUCTION PRACTICES  ALL UTILIZATION PRACTICES
# 8691        DRY               IN THE OPEN  ALL UTILIZATION PRACTICES
# 9476        DRY  ALL PRODUCTION PRACTICES  ALL UTILIZATION PRACTICES
#
#        STATISTICCAT_DESC   UNIT_DESC  \
# 7882  AREA IN PRODUCTION  OPERATIONS
# ...
